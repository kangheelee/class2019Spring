# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import csv

# %%
html = urlopen("http://cchart.xyz/ytcollect/YoutubeChannelTrackingServiceV2/beauty/1")
html

# %%
bsObject = BeautifulSoup(html, "html.parser")
bsObject.html
# Out:
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="cchart.xyz에서 제공하는  카테고리 한국 채널 순위(랭킹) 확인해보세요. 채널 이름을 선택하면 나오는 상세 정보에는 더 자세한 많은 정보가 있습니다. 여러 분이 좋아하는 채널들을 검색하고 구독하세요. " name="description"/>
# <title>유튜브 랭킹(순위) 한국채널 정보 -  - cchart.xyz</title>
# <link href="http://example.ampproject.org/article-metadata.html" rel="canonical"/>
# <meta content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/>
# <style amp-boilerplate="">
#     body {
#         -webkit-animation: -amp-start 8s steps(1, end) 0s 1 normal both;
#         -moz-animation: -amp-start 8s steps(1, end) 0s 1 normal both;
#         -ms-animation: -amp-start 8s steps(1, end) 0s 1 normal both;
#         animation: -amp-start 8s steps(1, end) 0s 1 normal both
#     }
#
#     @-webkit-keyframes -amp-start {
#         from {
#             visibility: hidden
#         }
#         to {
#             visibility: visible
#         }
#     }
#
#     @-moz-keyframes -amp-start {
#         from {
# ...

# %%
for link in bsObject.find_all('plus_data'):
    print(link.text.strip(), link.get('ci'))
